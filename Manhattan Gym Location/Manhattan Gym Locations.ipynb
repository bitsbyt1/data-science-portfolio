# %%
#conda install -c conda-forge geopy

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10 )
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
from folium import plugins
from folium.plugins import HeatMap

# %% [markdown]
# ---
# ### **Introduction: Business Problem**
#
#
# Analyzing the number of fitness centers in Manhattan, New York to decide where would be a good location to start a new gym.
#
# Who would be interested in this project: Investors and business owners who would like to start a gym, as well as fitness enthusiasts who would like to live closer to a ym or fitness center
#
# ---

# %% [markdown]
# ### **Data**
#
# I used the '**newyork_data.json**' dataset from IBM, as well as the Foursqaure API to get the information on gyms and fitness centers in Manhattan

# %% [markdown]
# ### **Methodology**
#
# I started off by loading the **newyork_data.json** Json file into a data set. I organized the data set into four columns - Borough, Neighborhood, Latitude and Longitude.
#
# I then took the data from the new york dataset and created a new dataset for just Manhattan, which consisted of clusters of all the Neighborhoods in Manhattan using their Latitude and Longitude coordinates
#
# After that I used the Foursquare API combined with the Manhattan Neighborhood Dataset to get a list of every Gym and Fitness center in the Borough along with their Latitude and Longitudes.
#
# Then using Folium I generated a heatmap to see the density or 'heat' of the number of Gyms and Fitness Centers in different parts of Manhattan

# %%
# !wget -q -O 'newyork_data.json' https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json

# %%
with open('newyork_data.json') as json_data:
  newyork_data = json.load(json_data)

# %%
#print(newyork_data)

# %%
neighborhoods_data = newyork_data['features']
neighborhoods_data[0:2]
# Out:
# [{'type': 'Feature',
#   'id': 'nyu_2451_34572.1',
#   'geometry': {'type': 'Point',
#    'coordinates': [-73.84720052054902, 40.89470517661]},
#   'geometry_name': 'geom',
#   'properties': {'name': 'Wakefield',
#    'stacked': 1,
#    'annoline1': 'Wakefield',
#    'annoline2': None,
#    'annoline3': None,
#    'annoangle': 0.0,
#    'borough': 'Bronx',
#    'bbox': [-73.84720052054902,
#     40.89470517661,
#     -73.84720052054902,
#     40.89470517661]}},
#  {'type': 'Feature',
#   'id': 'nyu_2451_34572.2',
#   'geometry': {'type': 'Point',
#    'coordinates': [-73.82993910812398, 40.87429419303012]},
#   'geometry_name': 'geom',
#   'properties': {'name': 'Co-op City',
#    'stacked': 2,
#    'annoline1': 'Co-op',
#    'annoline2': 'City',
#    'annoline3': None,
#    'annoangle': 0.0,
#    'borough': 'Bronx',
#    'bbox': [-73.82993910812398,
#     40.87429419303012,
#     -73.82993910812398,
#     40.87429419303012]}}]

# %%
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude']
neighborhoods = pd.DataFrame(columns=column_names)
neighborhoods
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
for data in neighborhoods_data:
  borough = neighborhood_name = data['properties']['borough']
  neighborhood_name = data['properties']['name']
  neighborhood_latlon = data['geometry']['coordinates']
  neighborhood_lat = neighborhood_latlon[1]
  neighborhood_lon = neighborhood_latlon[0]

  neighborhoods = neighborhoods.append({'Borough': borough,
                                        'Neighborhood': neighborhood_name,
                                        'Latitude': neighborhood_lat,
                                        'Longitude': neighborhood_lon}, ignore_index = True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)

# %%
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %% [markdown]
# ### **Analysis**
#
# As you can see, Manhattan is denser (has more neighborhoods) toward the water and the South West end of the borough, and less dense in the North East end.

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
manhattan_center = [latitude, longitude]
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
print(manhattan_center)
# Out:
# The geograpical coordinate of Manhattan are 40.7896239, -73.9598939.
# [40.7896239, -73.9598939]

# %%
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_abbcf4ea109f4a728d599bb6b89e603b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_abbcf4ea109f4a728d599bb6b89e603b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_abbcf4ea109f4a728d599bb6b89e603b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_abbcf4ea109f4a728d599bb6b89e603b%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7896239%2C-73.9598939%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
CLIENT_ID = 'SQJU3NP5PSZZ4SEHGSC3ILIU3VPY0VMHAQNU1JWLKMNYN2GA' # your Foursquare ID
CLIENT_SECRET = 'P3SDDVEOOGVU2W5A4DJLOVREYURICFU000DDYLDJ3HHISJ4V' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SQJU3NP5PSZZ4SEHGSC3ILIU3VPY0VMHAQNU1JWLKMNYN2GA
# CLIENT_SECRET:P3SDDVEOOGVU2W5A4DJLOVREYURICFU000DDYLDJ3HHISJ4V

# %%
manhattan_data
# Out:
#       Borough        Neighborhood   Latitude  Longitude
# 0   Manhattan         Marble Hill  40.876551 -73.910660
# 1   Manhattan           Chinatown  40.715618 -73.994279
# 2   Manhattan  Washington Heights  40.851903 -73.936900
# 3   Manhattan              Inwood  40.867684 -73.921210
# 4   Manhattan    Hamilton Heights  40.823604 -73.949688
# ..        ...                 ...        ...        ...
# 35  Manhattan          Turtle Bay  40.752042 -73.967708
# 36  Manhattan          Tudor City  40.746917 -73.971219
# 37  Manhattan     Stuyvesant Town  40.731000 -73.974052
# 38  Manhattan            Flatiron  40.739673 -73.990947
# 39  Manhattan        Hudson Yards  40.756658 -74.000111
#
# [40 rows x 4 columns]

# %%
LIMIT = 100
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=SQJU3NP5PSZZ4SEHGSC3ILIU3VPY0VMHAQNU1JWLKMNYN2GA&client_secret=P3SDDVEOOGVU2W5A4DJLOVREYURICFU000DDYLDJ3HHISJ4V&v=20180605&ll=40.7896239,-73.9598939&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '614b5101b7b31a07c58f840d'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Central Park',
#   'headerFullLocation': 'Central Park, New York',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 28,
#   'suggestedBounds': {'ne': {'lat': 40.794123904500005,
#     'lng': -73.95396136384342},
#    'sw': {'lat': 40.7851238955, 'lng': -73.96582643615658}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a78425df964a52053e51fe3',
#        'name': 'Central Park Tennis Center',
#        'location': {'address': 'Central Park West at 96th St',
#         'lat': 40.78931319964619,
#         'lng': -73.96186241658044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.78931319964619,
#           'lng': -73.96186241658044}],
#         'distance': 169,
#         'postalCode': '10024',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Central Park West at 96th St',
#          'New York, NY 10024',
#          'United States']},
#        'categories': [{'id': '4e39a956bd410d7aed40cbc3',
#          'name': 'Tennis Court',
#          'pluralName': 'Tennis Courts',
#          'shortName': 'Tennis Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_tennis_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a78425df964a52053e51fe3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba233dbf964a5206fe337e3',
#        'name': 'East Meadow',
#        'location': {'address': 'Central Park',
#         'crossStreet': '5th Ave btwn 98th & 101st St',
#         'lat': 40.79015961797437,
#         'lng': -73.95549774169922,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79015961797437,
#           'lng': -73.95549774169922}],
#         'distance': 375,
#         'postalCode': '10029',
#         'cc': 'US',
#         'neighborhood': 'Central Park',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Central Park (5th Ave btwn 98th & 101st St)',
#          'New York, NY 10029',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15f941735',
#          'name': 'Field',
#          'pluralName': 'Fields',
#          'shortName': 'Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/field_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba233dbf964a5206fe337e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc27efd461576b047917d32',
#        'name': 'North Meadow Recreation Center',
#        'location': {'address': '97th St Transverse Rd',
#         'lat': 40.79121558394569,
#         'lng': -73.95966053009033,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79121558394569,
#           'lng': -73.95966053009033}],
#         'distance': 178,
#         'postalCode': '10028',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['97th St Transverse Rd',
#          'New York, NY 10028',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a26',
#          'name': 'Recreation Center',
#          'pluralName': 'Recreation Centers',
#          'shortName': 'Recreation Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc27efd461576b047917d32-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3c0584e4b0f7c8c775c07e',
#        'name': 'Oldest Tree in Central Park',
#        'location': {'address': 'Northern end of the Reservoir, Bridle Path',
#         'crossStreet': '~96th St',
#         'lat': 40.78918805591645,
#         'lng': -73.9578668065709,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.78918805591645,
#           'lng': -73.9578668065709}],
#         'distance': 177,
#         'postalCode': '10024',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Northern end of the Reservoir, Bridle Path (~96th St)',
#          'New York, NY 10024',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f3c0584e4b0f7c8c775c07e-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8adef1f964a520728632e3',
#        'name': 'Central Park - Wild West Playground',
#        'location': {'address': 'Central Park West',
#         'crossStreet': '93rd Street',
#         'lat': 40.78971453280016,
#         'lng': -73.96547065045945,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.78971453280016,
#           'lng': -73.96547065045945}],
#         'distance': 470,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Central Park West (93rd Street)',
#          'New York, NY',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8adef1f964a520728632e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a621e5bf964a52021c31fe3',
#        'name': 'Central Park - 96th Street Playground',
#        'location': {'address': '1141 5th Ave',
#         'crossStreet': '96th Street',
#         'lat': 40.78781327170276,
#         'lng': -73.95625668316937,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.78781327170276,
#           'lng': -73.95625668316937}],
#         'distance': 366,
#         'postalCode': '10128',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1141 5th Ave (96th Street)',
#          'New York, NY 10128',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a621e5bf964a52021c31fe3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c82547647cc224b1e61849f',
#        'name': 'North Meadow Field 2',
#        'location': {'address': 'Central Park',
#         'crossStreet': 'btwn 98th & 97th St',
#         'lat': 40.792230920004314,
#         'lng': -73.96108746528625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.792230920004314,
#           'lng': -73.96108746528625}],
#         'distance': 307,
#         'postalCode': '10128',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Central Park (btwn 98th & 97th St)',
#          'New York, NY 10128',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c82547647cc224b1e61849f-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6331414554a0934064afaa',
#        'name': 'Central Park - 99th & 5th Ave',
#        'location': {'crossStreet': '99th Ave &  5th Ave',
#         'lat': 40.78879138916376,
#         'lng': -73.95523207333972,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.78879138916376,
#           'lng': -73.95523207333972}],
#         'distance': 403,
#         'postalCode': '10029',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['99th Ave &  5th Ave',
#          'New York, NY 10029',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6331414554a0934064afaa-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd7d88de4cd37c893b54b37',
#        'name': 'North Meadow Field 9',
#        'location': {'address': '103rd St',
#         'lat': 40.79228371705468,
#         'lng': -73.95634800195694,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79228371705468,
#           'lng': -73.95634800195694}],
#         'distance': 420,
#         'postalCode': '10025',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['103rd St',
#          'New York, NY 10025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd7d88de4cd37c893b54b37-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a591442f964a5209fb81fe3',
#        'name': 'Robert Bendheim Playground',
#        'location': {'address': '1190 5th Ave',
#         'crossStreet': 'E 100 St',
#         'lat': 40.790253713015055,
#         'lng': -73.95415038514743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.790253713015055,
#           'lng': -73.95415038514743}],
#         'distance': 489,
#         'postalCode': '10029',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1190 5th Ave (E 100 St)',
#          'New York, NY 10029',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a591442f964a5209fb81fe3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a1c1832f964a5200d7b1fe3',
#        'name': 'Rudin Family Playground',
#        'location': {'address': 'Central Park West',
#         'crossStreet': 'W 96th St',
#         'lat': 40.791821759772205,
#         'lng': -73.96414735066456,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.791821759772205,
#           'lng': -73.96414735066456}],
#         'distance': 434,
#         'postalCode': '10025',
#         'cc': 'US',
#         'neighborhood': 'Central Park',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Central Park West (W 96th St)',
#          'New York, NY 10025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a1c1832f964a5200d7b1fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e74e8f98998ed82a444cf3b',
#        'name': 'Central Park - 97th St Transverse',
#        'location': {'lat': 40.78851452846438,
#         'lng': -73.95510378239035,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.78851452846438,
#           'lng': -73.95510378239035}],
#         'distance': 422,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY', 'United States']},
#        'categories': [{'id': '4d4b7105d754a06377d81259',
#          'name': 'Outdoors & Recreation',
#          'pluralName': 'Outdoors & Recreation',
#          'shortName': 'Outdoors & Recreation',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e74e8f98998ed82a444cf3b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58fcd7614940bc7da760ed94',
#        'name': 'North Meadow Basketball Courts',
#        'location': {'address': '96th St Transverse Rd',
#         'lat': 40.791283,
#         'lng': -73.959412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.791283,
#           'lng': -73.959412}],
#         'distance': 189,
#         'postalCode': '10028',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['96th St Transverse Rd',
#          'New York, NY 10028',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e1941735',
#          'name': 'Basketball Court',
#          'pluralName': 'Basketball Courts',
#          'shortName': 'Basketball Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58fcd7614940bc7da760ed94-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '556a19e4498e15ee7f43c30d',
#        'name': 'North Meadow Field 12',
#        'location': {'lat': 40.791393840006116,
#         'lng': -73.95816922187805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.791393840006116,
#           'lng': -73.95816922187805}],
#         'distance': 244,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-556a19e4498e15ee7f43c30d-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c60860354ac0f4735cdb521',
#        'name': 'North Meadow Field 11',
#        'location': {'address': 'Central Park',
#         'crossStreet': 'at 97th St Transverse Rd',
#         'lat': 40.79159102748493,
#         'lng': -73.95809055891252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79159102748493,
#           'lng': -73.95809055891252}],
#         'distance': 266,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Central Park (at 97th St Transverse Rd)',
#          'New York, NY',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c60860354ac0f4735cdb521-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8c47d3b118b71384021901',
#        'name': 'Central Park - East Drive',
#        'location': {'address': '6th Ave',
#         'crossStreet': 'btw 83rd & 84th Sts',
#         'lat': 40.790971900981276,
#         'lng': -73.95631313323975,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.790971900981276,
#           'lng': -73.95631313323975}],
#         'distance': 337,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['6th Ave (btw 83rd & 84th Sts)',
#          'New York, NY',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8c47d3b118b71384021901-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd32216cc3fc3ce876e9393',
#        'name': 'North Meadow Field 1',
#        'location': {'address': 'W 100th St',
#         'lat': 40.79293910771353,
#         'lng': -73.96058320999146,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79293910771353,
#           'lng': -73.96058320999146}],
#         'distance': 373,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['W 100th St', 'New York, NY', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd32216cc3fc3ce876e9393-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b530c034ac28a002c1a801a',
#        'name': 'QDR Rock',
#        'location': {'address': 'Central Park East Drive',
#         'crossStreet': 'E 99th Street',
#         'lat': 40.791431,
#         'lng': -73.956049,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.791431,
#           'lng': -73.956049}],
#         'distance': 381,
#         'postalCode': '10025',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Central Park East Drive (E 99th Street)',
#          'New York, NY 10025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b530c034ac28a002c1a801a-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51633c3e498e18f69d1c273e',
#        'name': 'North Meadow Field 5',
#        'location': {'lat': 40.79310409659672,
#         'lng': -73.95875930786133,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79310409659672,
#           'lng': -73.95875930786133}],
#         'distance': 399,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51633c3e498e18f69d1c273e-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b94f621f964a520808934e3',
#        'name': 'W. 94th St. Canine Congregation',
#        'location': {'lat': 40.78993237155176,
#         'lng': -73.96462818110523,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.78993237155176,
#           'lng': -73.96462818110523}],
#         'distance': 400,
#         'cc': 'US',
#         'state': 'New York',
#         'country': 'United States',
#         'formattedAddress': ['New York', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'shortName': 'Dog Run',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b94f621f964a520808934e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '519410f4498ee179aaec73ea',
#        'name': 'North Meadow Field 10',
#        'location': {'lat': 40.79207718585043,
#         'lng': -73.95634562497074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79207718585043,
#           'lng': -73.95634562497074}],
#         'distance': 404,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-519410f4498ee179aaec73ea-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de154b0fa7651589ee40101',
#        'name': 'North Meadow Field 6',
#        'location': {'lat': 40.79290509456972,
#         'lng': -73.95752549171448,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79290509456972,
#           'lng': -73.95752549171448}],
#         'distance': 416,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de154b0fa7651589ee40101-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '501da5f2e4b087a0ae2c672d',
#        'name': 'North Meadow Field 7',
#        'location': {'lat': 40.79270138767761,
#         'lng': -73.95708033593266,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79270138767761,
#           'lng': -73.95708033593266}],
#         'distance': 416,
#         'postalCode': '10025',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY 10025', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e8941735',
#          'name': 'Baseball Field',
#          'pluralName': 'Baseball Fields',
#          'shortName': 'Baseball Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-501da5f2e4b087a0ae2c672d-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f7f6d18e4b075c306948c9b',
#        'name': 'Original Wolf Den',
#        'location': {'lat': 40.79214943837445,
#         'lng': -73.96367538956173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79214943837445,
#           'lng': -73.96367538956173}],
#         'distance': 424,
#         'cc': 'US',
#         'country': 'United States',
#         'formattedAddress': ['United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f7f6d18e4b075c306948c9b-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c8aa67498e17c452a4c157',
#        'name': 'Citi Bike Station',
#        'location': {'lat': 40.791631,
#         'lng': -73.964762,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.791631,
#           'lng': -73.964762}],
#         'distance': 467,
#         'postalCode': '10025',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY 10025', 'United States']},
#        'categories': [{'id': '4e4c9077bd41f78e849722f9',
#          'name': 'Bike Rental / Bike Share',
#          'pluralName': 'Bike Rentals / Bike Shares',
#          'shortName': 'Bike',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c8aa67498e17c452a4c157-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0eed54f964a520e55c23e3',
#        'name': 'MTA Subway - 96th St (B/C)',
#        'location': {'address': '96th St',
#         'crossStreet': 'at Central Park West',
#         'lat': 40.79177462584017,
#         'lng': -73.96479310155709,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79177462584017,
#           'lng': -73.96479310155709}],
#         'distance': 477,
#         'postalCode': '10025',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['96th St (at Central Park West)',
#          'New York, NY 10025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fd931735',
#          'name': 'Metro Station',
#          'pluralName': 'Metro Stations',
#          'shortName': 'Metro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0eed54f964a520e55c23e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '596d000ead17897fe02084ee',
#        'name': 'MTA Bus - M96/M106 (CPW & W 96th St)',
#        'location': {'lat': 40.79171,
#         'lng': -73.964933,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.79171,
#           'lng': -73.964933}],
#         'distance': 484,
#         'postalCode': '10025',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY 10025', 'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#          'name': 'Bus Stop',
#          'pluralName': 'Bus Stops',
#          'shortName': 'Bus Stop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-596d000ead17897fe02084ee-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f9f186be4b03ad9ab89e653',
#        'name': 'Bus Stop 96th & Central Park West',
#        'location': {'address': 'W. 96th St.',
#         'crossStreet': 'Central Park West',
#         'lat': 40.7918693341868,
#         'lng': -73.96484054966295,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7918693341868,
#           'lng': -73.96484054966295}],
#         'distance': 486,
#         'postalCode': '10025',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['W. 96th St. (Central Park West)',
#          'New York, NY 10025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f9f186be4b03ad9ab89e653-27'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues)

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# <ipython-input-29-3a23abf09381>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues)
#                                   name         categories        lat  \
# 0           Central Park Tennis Center       Tennis Court  40.789313
# 1                          East Meadow              Field  40.790160
# 2       North Meadow Recreation Center  Recreation Center  40.791216
# 3          Oldest Tree in Central Park               Park  40.789188
# 4  Central Park - Wild West Playground         Playground  40.789715
#
#          lng
# 0 -73.961862
# 1 -73.955498
# 2 -73.959661
# 3 -73.957867
# 4 -73.965471

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 28 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
manhattan_venues = getNearbyVenues(names = manhattan_data['Neighborhood'],
                                  latitudes = manhattan_data['Latitude'],
                                  longitudes = manhattan_data['Longitude'])
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %%
print(manhattan_venues.shape)
manhattan_venues.head()
# Out:
# (3276, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude          Venue  \
# 0  Marble Hill              40.876551               -73.91066    Bikram Yoga
# 1  Marble Hill              40.876551               -73.91066       Arturo's
# 2  Marble Hill              40.876551               -73.91066  Tibbett Diner
# 3  Marble Hill              40.876551               -73.91066        Dunkin'
# 4  Marble Hill              40.876551               -73.91066      Starbucks
#
#    Venue Latitude  Venue Longitude Venue Category
# 0       40.876844       -73.906204    Yoga Studio
# 1       40.874412       -73.910271    Pizza Place
# 2       40.880404       -73.908937          Diner
# 3       40.877136       -73.906666     Donut Shop
# 4       40.877531       -73.905582    Coffee Shop

# %% [markdown]
# Filter out Neighborhoods with Gyms or Fitness Centers

# %%
fitness_venues_list = ['Gym', 'Gym / Fitness Center']
manhattan_gyms = manhattan_venues[manhattan_venues['Venue Category'].isin(fitness_venues_list)]
manhattan_gyms.head()
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 5           Marble Hill              40.876551               -73.91066
# 6           Marble Hill              40.876551               -73.91066
# 165  Washington Heights              40.851903               -73.93690
# 182  Washington Heights              40.851903               -73.93690
# 208  Washington Heights              40.851903               -73.93690
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 5    Astral Fitness & Wellness Center       40.876705       -73.906372
# 6                       Blink Fitness       40.877271       -73.905595
# 165                    Planet Fitness       40.847536       -73.937937
# 182                     Blink Fitness       40.848562       -73.936941
# 208                   Lucille Roberts       40.848487       -73.934636
#
#            Venue Category
# 5                     Gym
# 6                     Gym
# 165  Gym / Fitness Center
# 182                   Gym
# 208                   Gym

# %% [markdown]
# ### **Analysis Continued**
#
# Here we see a heatmap of the gyms and fitness centers and you can immediately notice that there are more gyms towards the Southern end of Manhattan than the Northern end (much like the density of the neighborhoods)

# %%
gyms_latlongs = manhattan_gyms[['Venue Latitude', 'Venue Longitude']]
gyms_latlongs_list = gyms_latlongs.values.tolist()

# %%
manhattan_neighborhood_latlongs = manhattan_gyms[['Neighborhood Latitude', 'Neighborhood Longitude']]
manhattan_neighborhood_latlongs_list = manhattan_neighborhood_latlongs.values.tolist()

# %%
def manhattan_neighborhood_style(feature):
    return { 'color': 'blue', 'fill': False }

# %%
heatmap_manhattan = folium.Map(location=[latitude, longitude], zoom_start=12, width = '50%', height = '70%')
folium.TileLayer('cartodbpositron').add_to(heatmap_manhattan)
HeatMap(gyms_latlongs_list).add_to(heatmap_manhattan)
folium.Marker(manhattan_center).add_to(heatmap_manhattan)
folium.Circle(manhattan_center, radius=3000, fill=False, color='white').add_to(heatmap_manhattan)
folium.Circle(manhattan_center, radius=6000, fill=False, color='white').add_to(heatmap_manhattan)
folium.Circle(manhattan_center, radius=9000, fill=False, color='white').add_to(heatmap_manhattan)
heatmap_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_fb06fd532eac41a89f4a30f510d6a9fe%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%2050.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%2070.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//leaflet.github.io/Leaflet.heat/dist/leaflet-heat.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fb06fd532eac41a89f4a30f510d6a9fe%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fb06fd532eac41a89f4a30f510d6a9fe%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_fb06fd532eac41a89f4a30f510d6a9fe%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7896239%2C-73.9598939%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### **Results and Discussion**
#
# Viewing the analysis shows us that Manhattan has a lot more neighborhoods towards its Southern end, and it also has more gyms and fitness centers in that direction.
#
# It seems to have the highest number of fitness centers in the Financial District and Upper East Side and very few in Harlem, Carnegie Hill and Manhattan Valley - these neighborhoods could be ideal oppurtunities in therms of the lack of fitness centers.

# %% [markdown]
# ---
#
# ### **Conclusion**
#
# This report simply explored the oppurtinity for opening a new gym or fitness center in Manhattan purely based on how many other fitness centers were in each neighborhood of Manhattan.
#
# A business owner has oppurtuny in the North side of Manhattan solely based on the advantage of the lack of competition, however it is encouraged to use this report as a guide to collect additional information on the less dense neighborhoods, such as income, population density and more.
