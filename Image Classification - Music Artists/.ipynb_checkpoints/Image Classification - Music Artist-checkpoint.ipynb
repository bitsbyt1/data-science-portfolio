# %%
import numpy as np
import cv2
import matplotlib

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/Users/tahermn/Documents/Programming/Data Science Portfolio/Image Classification - Music Artists/model/test_images/ed_sheeran_test_image.jpeg')
img.shape
# Out:
# (2000, 2000, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (2000, 2000)

# %%
plt.imshow(gray)

# %%
plt.imshow(gray, cmap = 'gray')

# %%
face_cascade = ('./')
